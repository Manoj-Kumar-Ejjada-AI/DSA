# %% [markdown]
# <a href="https://colab.research.google.com/github/Manoj-Kumar-Ejjada-AI/DSA/blob/main/recursion/code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Print a name `N` times

# %%
def print_name_n_times(i,n):
  if i>n:
    return
  print("Name")
  print_name_n_times(i+1,n)

# %%
print_name_n_times(1,3)
# Out:
# Name
# Name
# Name

# %% [markdown]
# ## Print from 1 to `N`

# %%
def print_1_to_n(i,n):
  if i>n:
    return
  print(i)
  print_1_to_n(i+1,n)

# %%
print_1_to_n(1,3)
# Out:
# 1
# 2
# 3

# %% [markdown]
# ## Print Linearly from 1 to `N`

# %%
def print_1_to_n_linearly(i,n):
  if i > n:
    return
  print(i, end = " ")
  print_1_to_n_linearly(i+1,n)

# %%
print_1_to_n_linearly(1,5)
# Out:
# 1 2 3 4 5

# %% [markdown]
# ## Print Linearly from `N` to 1

# %%
def print_n_to_1_linearly(n):
  if n == 0:
    return
  print(n, end = " ")
  print_n_to_1_linearly(n-1)

# %%
print_n_to_1_linearly(5)
# Out:
# 5 4 3 2 1
